# %% [markdown]
# (response)=
# # Response, 🪙 🎲 🎰 🐜 🗡️ 🪖 🛡️
#
# <style>
#   /* Apply styles only to elements with the custom class */
#   .custom-details summary {
#     list-style: none;  /* Remove default dropdown triangle */
#     cursor: pointer;
#     font-weight: normal; /* Normal text weight */
#     display: inline-block;
#     padding: 5px 15px;
#     border: 2px dotted black; /* Dotted circle */
#     border-radius: 20px; /* Make it rounded */
#     text-align: center;
#     transition: color 0.3s ease-in-out; /* Smooth transition */
#   }
#
#   .custom-details summary:hover {
#     color: lightgray; /* Change text color on hover */
#   }
#
#   .custom-details summary::-webkit-details-marker {
#     display: none; /* Remove marker in WebKit (Chrome, Safari) */
#   }
# </style>
#
# <details class="custom-details">
#   <summary>+ Expand</summary>
#   <iframe src="pdfs/CJCS_Memo.pdf" width="100%" height="1000px" style="borders:none"></iframe>
#   <blockquote style="border-left: 4px solid #ccc; padding-left: 10px; color: #555;">
#     <em>
#       <details>
#         <summary></summary>
#         <ol start="1">
#           <li>The first portrait of Gen. Milley, from his time as the U.S. military's top officer, was removed from the Pentagon last week on Inauguration Day less than two hours after President Trump was sworn into office.</li>
#           <li>The now retired Gen. Milley and other former senior Trump aides had been assigned personal security details ever since Iran vowed revenge for the killing of Qasem Soleimani in a drone strike in 2020 ordered by Trump in his first term.</li>
#           <li>On "Fox News Sunday," the chairman of the Senate Intelligence Committee, Tom Cotton, said he hoped President Trump would "revisit" the decision to pull the protective security details from John Bolton, Mike Pompeo, and Brian Hook who previously served under Trump.</li>
#           <li>A senior administration official who requested anonymity replied, "There is a new era of accountability in the Defense Department under President Trump's leadership—and that's exactly what the American people expect."</li>
#           <li>Gen. Milley served as chairman of the Joint Chiefs of Staff from 2019 to 2023 under both Presidents Trump and Biden.</li>
#         </ol>
#       </details>
#     </em>
#     <p>--<a href="https://www.foxnews.com/politics/white-house-pulling-gen-milleys-security-detail-clearance-panel-may-face-demotion-retirement.amp"> Fox News</a></p>
#   </blockquote>
# </details>
#
# <script>
#   document.addEventListener("DOMContentLoaded", function() {
#     const details = document.querySelector(".custom-details");
#     const summary = details.querySelector("summary");
#
#     details.addEventListener("toggle", function() {
#       summary.textContent = details.open ? "- Collapse" : "+ Expand";
#     });
#   });
# </script>
#
# <p></p>
# <p></p>
#
# **A Book on Salience, Absurdity, and the Ragtime of Being**
#
# “I am afraid you don’t quite see the moral of the story,” remarked the Linnet, perched primly on a twig of thought, feathers ruffled by the weight of its own cleverness. “The what?” screamed the Water-rat, all whiskers and indignation, splashing in the muddy pool of existence. “The moral.” “Do you mean to say that the story has a moral?” “Certainly,” said the Linnet, with the smugness of a bird who’s pecked at too many Victorian crumbs. “Well, really,” retorted the Water-rat, tail whisking like a metronome to some unheard rag, “I think you should have told me that before you began. If you had done so, I certainly would not have listened to you; in fact, I should have said ‘Pooh,’ like the critic. However, I can say it now.” And so he bellowed “Pooh!” at the top of his lungs, gave a syncopated flick of his tail, and retreated into the hole of his own absurdity. The Duck paddled up moments later, all maternal sighs and watery tears. “How do you like the Water-rat?” she asked. “He has his points, but I can’t look at a confirmed bachelor without weeping.” “I fear I’ve annoyed him,” said the Linnet. “I told him a story with a moral.” “Ah! That is always a very dangerous thing to do,” quacked the Duck. And I quite agree with her.
#
# ```{figure} figures/shruti.*
# ---
# width: 20%
# height: 20%
# ---
# _Digital Library_. Our color-coded QR code library with a franchize model for the digital twin will be launched in a month. The books will explore struggle, exchange, and consolidation as dynamic equilibria that emerge from the oscillation and rhythm of existence.
# ```
#
# So begins Oscar Wilde’s little parable from *[The Devoted Friend](https://www.gutenberg.org/cache/epub/902/pg902-images.html)*, a fin-de-siècle jab at the sanctimonious air of Victorian storytelling, all wrapped in a cadence that dances like a ragtime tune—light, irreverent, and thumbing its nose at the cathedrals of moral grand-standing. Wilde, who shuffled off this mortal coil in 1900, shared that year of exit with Friedrich Nietzsche, a kindred spirit in epigrams and witticisms. Both detested the ponderous edifices of grand essays and structured systems—those towering spires of thought that reeked of sermonizing. Wilde spun fables to expose the absurdity of earnestness; Nietzsche wielded his hammer to smash the idols of certainty. Neither would have much patience for the modern neuroscientific penchant for mapping the mind into neat networks, yet here we are, stitching their spirits into a tale of salience and syncopation. For I’d like to think of the salient network—that cingulo-insular maestro—as an optimizing algorithm, a ragtime pianist tying together the discordant keys of the brain’s orchestra: the Pericentral reflex, the Dorsal Frontoparietal gaze, the Lateral Frontoparietal shuffle, the Medial Frontoparietal mirror, and its own Cingulo-Insular rhythm. In doing so, it reveals the absurdity of the entire enterprise—cadences and all.
#
# ```{admonition} Ecclesiastes 3:8
# :class: danger
# *A time to love, and a time to hate; a time of war, and a time of peace*
# ```
#
# Picture the scene: the brain as a ragtime band, each network a player in a fin-de-siècle saloon. First, the Pericentral network bangs the drum of reflex—boom, a hand jerks from the flame, a colony recoils from the boot. It’s the Water-rat’s “Pooh!”—instinctive, unthinking, a primal whisk of the tail. Wilde would nod approvingly; there’s no moral here, just survival’s blunt beat. Nietzsche might call it the will to power in its rawest form, a twitch against the world’s impositions. Then comes the Dorsal Frontoparietal network, eyes sharp as a hawk, picking out the nonself—the hot stove, the colonial flag, the upstart crow stealing feathers. It’s the Linnet’s smug certainty, spotting threats and opportunities with a bird’s-eye view, yet blind to its own pomposity. For Nietzsche, it’s the gaze of the overman, discerning what to affirm or negate, though Wilde would smirk at its seriousness.
#
# Enter the Lateral Frontoparietal network, the improviser of the bunch, riffing on ambiguity like a pianist syncopating between keys. It weighs self and nonself in a jaunty dance—tribal roots against imposed laws, Shakespeare’s borrowed plumes against Greene’s outrage. Here’s where the Duck paddles in, tears for the bachelor Water-rat mingling with the absurdity of indecision. Wilde would revel in this gray space, where morals falter and wit reigns; Nietzsche might see it as the eternal recurrence of choice, absurd yet free. The Medial Frontoparietal network turns inward, a crooner gazing into the mirror of self—memory, identity, the “I” that Africa or Uganda or even Shakespeare forged from chaos. It’s the Linnet’s moral, clinging to coherence, though Wilde would scoff at its earnestness, and Nietzsche would shatter its illusions with a laugh.
#
# ```{admonition} The Dude's Rug
# :class: important
# 1. Pericentral. Water-rat
# 2. Dorsal. Linnet
# 3. Lateral. Duck
# 4. Medial. Water-rat, Linnet, Duck
# 5. Cingulo-Insular. Rhythm
# ```
#
# Finally, the Cingulo-Insular network—the salient maestro—ties it all together, an optimizing algorithm with a ragtime swing. It’s the bandleader, syncing the reflex to the gaze, the shuffle to the croon, balancing salience like a juggler with too many pins. In biology, it sifts threats from noise, pathogens from self; in history, it’s Africa’s dream of convergence, blending colonial scars with tribal roots. Wilde might call it a dandy’s pose—elegant, absurd, and utterly useless—while Nietzsche would hear the Dionysian beat, chaos harmonized but never tamed. Together, these five networks play a tune that’s less a cathedral of meaning and more a saloon of absurdity, each cadence revealing the folly of seeking a grand moral.
#
# Take Wilde’s Water-rat and Linnet, then. The Water-rat’s retreat—his “Pooh!”—is the Pericentral reflex, rejecting the nonself of a moral tale. The Linnet’s prattle is the Dorsal focus, fixated on its own narrative, while the Duck’s tears waver in Lateral ambiguity, caught between judgment and sentiment. The Medial network hums in the Linnet’s self-assured identity, a bird convinced of its wisdom, until the Cingulo-Insular salience cuts through: the Duck’s quack—“that is always a very dangerous thing to do”—lands the punchline, optimizing the scene into absurdity. Nietzsche’s Zarathustra might laugh from the sidelines, seeing no moral but the joy of the jest. Africa’s history echoes this: the Pericentral flinch against colonialism, the Dorsal eye on foreign flags, the Lateral blur of hybridity, the Medial grasp for a unified self—all orchestrated by a Cingulo-Insular hope of convergence, yet landing in a ragtime of unresolved tensions.
#
# What’s the moral, then? Wilde and Nietzsche would recoil at the question, and rightly so. The salient network doesn’t preach; it plays. It’s an algorithm not of answers but of rhythm, syncing the brain’s cacophony into a tune that mocks its own structure. Your “Victorian cadence” meets “dudes rag” here—a fin-de-siècle strut through the absurdity of identity, whether in Wilde’s fables, Nietzsche’s aphorisms, or Africa’s saga. The enterprise—neural, historical, literary—unfurls as a grand joke: five networks, five players, all cadences in a rag that uncovers the truth: there’s no moral, only the dance.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define the neural network layers
def define_layers():
    return {
        'Suis': ['DNA, RNA,  5%', 'Peptidoglycans, Lipoteichoics', 'Lipopolysaccharide', 'N-Formylmethionine', "Glucans, Chitin", 'Specific Antigens'],
        'Voir': ['PRR & ILCs, 20%'],  
        'Choisis': ['CD8+, 50%', 'CD4+'],  
        'Deviens': ['TNF-α, IL-6, IFN-γ', 'PD-1 & CTLA-4', 'Tregs, IL-10, TGF-β, 20%'],  
        "M'èléve": ['Complement System', 'Platelet System', 'Granulocyte System', 'Innate Lymphoid Cells, 5%', 'Adaptive Lymphoid Cells']  
    }

# Assign colors to nodes
def assign_colors():
    color_map = {
        'yellow': ['PRR & ILCs, 20%'],  
        'paleturquoise': ['Specific Antigens', 'CD4+', 'Tregs, IL-10, TGF-β, 20%', 'Adaptive Lymphoid Cells'],  
        'lightgreen': ["Glucans, Chitin", 'PD-1 & CTLA-4', 'Platelet System', 'Innate Lymphoid Cells, 5%', 'Granulocyte System'],  
        'lightsalmon': ['Lipopolysaccharide', 'N-Formylmethionine', 'CD8+, 50%', 'TNF-α, IL-6, IFN-γ', 'Complement System'],
    }
    return {node: color for color, nodes in color_map.items() for node in nodes}

# Define edge weights
def define_edges():
    return {
        ('DNA, RNA,  5%', 'PRR & ILCs, 20%'): '1/99',
        ('Peptidoglycans, Lipoteichoics', 'PRR & ILCs, 20%'): '5/95',
        ('Lipopolysaccharide', 'PRR & ILCs, 20%'): '20/80',
        ('N-Formylmethionine', 'PRR & ILCs, 20%'): '51/49',
        ("Glucans, Chitin", 'PRR & ILCs, 20%'): '80/20',
        ('Specific Antigens', 'PRR & ILCs, 20%'): '95/5',
        ('PRR & ILCs, 20%', 'CD8+, 50%'): '20/80',
        ('PRR & ILCs, 20%', 'CD4+'): '80/20',
        ('CD8+, 50%', 'TNF-α, IL-6, IFN-γ'): '49/51',
        ('CD8+, 50%', 'PD-1 & CTLA-4'): '80/20',
        ('CD8+, 50%', 'Tregs, IL-10, TGF-β, 20%'): '95/5',
        ('CD4+', 'TNF-α, IL-6, IFN-γ'): '5/95',
        ('CD4+', 'PD-1 & CTLA-4'): '20/80',
        ('CD4+', 'Tregs, IL-10, TGF-β, 20%'): '51/49',
        ('TNF-α, IL-6, IFN-γ', 'Complement System'): '80/20',
        ('TNF-α, IL-6, IFN-γ', 'Platelet System'): '85/15',
        ('TNF-α, IL-6, IFN-γ', 'Granulocyte System'): '90/10',
        ('TNF-α, IL-6, IFN-γ', 'Innate Lymphoid Cells, 5%'): '95/5',
        ('TNF-α, IL-6, IFN-γ', 'Adaptive Lymphoid Cells'): '99/1',
        ('PD-1 & CTLA-4', 'Complement System'): '1/9',
        ('PD-1 & CTLA-4', 'Platelet System'): '1/8',
        ('PD-1 & CTLA-4', 'Granulocyte System'): '1/7',
        ('PD-1 & CTLA-4', 'Innate Lymphoid Cells, 5%'): '1/6',
        ('PD-1 & CTLA-4', 'Adaptive Lymphoid Cells'): '1/5',
        ('Tregs, IL-10, TGF-β, 20%', 'Complement System'): '1/99',
        ('Tregs, IL-10, TGF-β, 20%', 'Platelet System'): '5/95',
        ('Tregs, IL-10, TGF-β, 20%', 'Granulocyte System'): '10/90',
        ('Tregs, IL-10, TGF-β, 20%', 'Innate Lymphoid Cells, 5%'): '15/85',
        ('Tregs, IL-10, TGF-β, 20%', 'Adaptive Lymphoid Cells'): '20/80'
    }

# Define edges to be highlighted in black
def define_black_edges():
    return {
        ('DNA, RNA,  5%', 'PRR & ILCs, 20%'): '1/99',
        ('Peptidoglycans, Lipoteichoics', 'PRR & ILCs, 20%'): '5/95',
    }

# Calculate node positions
def calculate_positions(layer, x_offset):
    y_positions = np.linspace(-len(layer) / 2, len(layer) / 2, len(layer))
    return [(x_offset, y) for y in y_positions]

# Create and visualize the neural network graph
def visualize_nn():
    layers = define_layers()
    colors = assign_colors()
    edges = define_edges()
    black_edges = define_black_edges()
    
    G = nx.DiGraph()
    pos = {}
    node_colors = []
    
    # Create mapping from original node names to numbered labels
    mapping = {}
    counter = 1
    for layer in layers.values():
        for node in layer:
            mapping[node] = f"{counter}. {node}"
            counter += 1
            
    # Add nodes with new numbered labels and assign positions
    for i, (layer_name, nodes) in enumerate(layers.items()):
        positions = calculate_positions(nodes, x_offset=i * 2)
        for node, position in zip(nodes, positions):
            new_node = mapping[node]
            G.add_node(new_node, layer=layer_name)
            pos[new_node] = position
            node_colors.append(colors.get(node, 'lightgray'))
    
    # Add edges with updated node labels
    edge_colors = []
    for (source, target), weight in edges.items():
        if source in mapping and target in mapping:
            new_source = mapping[source]
            new_target = mapping[target]
            G.add_edge(new_source, new_target, weight=weight)
            edge_colors.append('black' if (source, target) in black_edges else 'lightgrey')
    
    # Draw the graph
    plt.figure(figsize=(12, 8))
    edges_labels = {(u, v): d["weight"] for u, v, d in G.edges(data=True)}
    
    nx.draw(
        G, pos, with_labels=True, node_color=node_colors, edge_color=edge_colors,
        node_size=3000, font_size=9, connectionstyle="arc3,rad=0.2"
    )
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edges_labels, font_size=8)
    plt.title("OPRAH™: Plato, Antiquarian, M-FPN", fontsize=18)
    plt.show()

# Run the visualization
visualize_nn()

# %% [markdown]
# ```{figure} https://www.ledr.com/colours/white.jpg
# ---
# width: 1
# height: 1
# ---
# _Veneration_. The antiquarian risks obsolescence if it doesn't engage with the new and emergent elements in the ecosystem. But modernity also drowns in noise when it becomes data-obsessed, algorithm driven, and skeptical of ancient wisdom including that from culture, ritual, and holy writ. In clinical research, LLMs offer a chance to unleash nuance and depth in various EHR treasure-troves locked in time-stamped patient records, clinical follow-up, laboratory and imaging, and ICD-tokenized billing records. This antiquarian "prosody" (in the beginning was the word) should transform the ecosystem and landscape dominated by a curated "grammar" of datasets, mostly numeric and static in nature.
# ```

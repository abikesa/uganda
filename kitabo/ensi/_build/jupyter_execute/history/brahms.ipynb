// %% [markdown]
// (brahms)=
// # Brahms
// # Art-Reverence, Science-Inference, Morality-Deliverance
//
//
// ```{tip}
// Call me an irreverent scientist, or ignorant artist, or biased moralist, and I'll say, huh.
// ```
//
// ```{warning}
// That sounds like someone who refuses to be boxed in, a true synthesis of multiple dimensions of thought. It’s as if you're rejecting any single label because none of them alone can contain the full complexity of what you're exploring—be it science, art, or morality. Is that what you're getting at?
// ```
//
// ```{margin}
//
// <Details>
//    <Summary></Summary>
//
// _Let's pick a leaf with regard to the "products" of academic research: Papers with embedded figures vs. Apps embedded in a Jupyter Book? Static vs. Dynamic? Final vs. Iterative?_ Nietzsche's aphoristic style reflects his philosophy perfectly—disjointed, sharp, and meant to `provoke` rather than `resolve`. It's fitting for someone who rejects linear narratives and grand teleological conclusions, as you pointed out with Marx and Dostoevsky. His idea of eternal recurrence, that life endlessly repeats without progress or redemption, clashes with the arcs that Dostoevsky’s tortured characters or Marx’s historical materialism offer. Those two are deeply invested in narrative arcs: Dostoevsky in the psychological and spiritual, Marx in the socio-political. Nietzsche, by contrast, thrives in fragmentation and repetition—the absence of a clean resolution is the point. It mirrors life’s chaotic, non-linear nature.
//
// He’s like a philosopher who enjoys the struggle but isn’t interested in wrapping it up with a bow. His style keeps the tension alive, which is his strength.
//
// </Details>

// %% [markdown]
// ```{margin}
//
// <Details>
//    <Summary></Summary>
//
// _Let's pick a leaf with regard to the "products" of academic research: Papers with embedded figures vs. Apps embedded in a Jupyter Book? Static vs. Dynamic? Final vs. Iterative?_ Nietzsche's aphoristic style reflects his philosophy perfectly—disjointed, sharp, and meant to `provoke` rather than `resolve`. It's fitting for someone who rejects linear narratives and grand teleological conclusions, as you pointed out with Marx and Dostoevsky. His idea of eternal recurrence, that life endlessly repeats without progress or redemption, clashes with the arcs that Dostoevsky’s tortured characters or Marx’s historical materialism` offer. Those two are deeply invested in narrative arcs: Dostoevsky in the psychological and spiritual, Marx in the socio-political. Nietzsche, by contrast, thrives in fragmentation and repetition—the absence of a clean resolution is the point. It mirrors life’s chaotic, non-linear nature.
//
// He’s like a philosopher who enjoys the struggle but isn’t interested in wrapping it up with a bow. His style keeps the tension alive, which is his strength.
//
// </Details>

// %% [markdown]
// ```{margin}
// <Details>
//    <Summary></Summary>
//
// - Phonetics
//    - e.g. Key
// - Temperament
//    - e.g. Degree
// - Scales/Modes
//    - e.g. Mixolydian ♭9♯9♭13 (aka Flamenco Phrygian)
// - Q-TEA
//    - Q
//       - ♭3
//       - Major
//       - Sus
//       - °
//       - +
//    - T
//       - 6
//       - 7,♭7,♭♭7
//    - E
//       - 9
//       - 11
//       - 13
//    - A
//       - ♭9♯9
//       - ♯11
//       - ♭13
// - NexToken/Pocket/Time
//    - Key, Orchestration
//    - Degree, Chord-Sequence
//       - Progression
//       - Non-progression
//    - Scale/Mode
//    - Q-TEA
//    - Rest
// - Emotion
//    - Arc (with Tension & Resolution)
//    - None (Hellenic & Pessimistic)
//
// `GPT`. This structure reads like a musical framework you’re organizing, particularly around harmony, theory, and emotional arcs. You're weaving together the building blocks of music—phonetics, temperament, scales, modes—and integrating a chordal theory system (Q-TEA) with deeper conceptual elements like time, orchestration, and emotion. Here's how I interpret the framework:
//
// 1. **Phonetics (e.g., Key)**
//    The basic sound unit, much like phonetics in language. A key establishes the tonal center.
//
// 2. **Temperament (e.g., Degree)**
//    Refers to the tuning system and intervals (degrees) within a scale. This introduces harmonic relationships.
//
// 3. **Scales/Modes (e.g., Flamenco Phrygian)**
//    Different patterns of notes, with exotic modes like Flamenco Phrygian offering complex tonalities and emotional color.
//
// 4. **Q-TEA: Chord Components**
//    This section breaks chords down into various components:
//    - **Q**: Root quality (♭3 for minor, Major, Suspended (sus), diminished (°), augmented (+)).
//    - **T**: Tension notes added to chords (6th, 7th, ♭7, ♭♭7).
//    - **E**: Extensions (9th, 11th, 13th).
//    - **A**: Alterations (♭9, ♯9, ♯11, ♭13) adding tension or color.
//
// 5. **NexToken/Pocket/Time**
//    This seems like the ‘beat,’ or how things evolve rhythmically and melodically:
//    - **Key, Orchestration**: Linking key signatures with orchestration choices.
//    - **Chord-sequence (Progression/Non-progression)**: The movement of chords, whether resolving or not.
//    - **Scale/Mode**: Modal decisions within the structure.
//    - **Q-TEA**: Chord alterations and extensions.
//    - **Rest**: Use of silence, creating tension.
//
// 6. **Emotion**
//    - **Arc**: An emotional trajectory through tension and resolution, like a story.
//    - **None (Hellenic & Pessimistic)**: The absence of emotional arcs, possibly referring to static or unresolved feelings, much like classical Greek tragedies or philosophical pessimism.
//
// The tension between structure and unpredictability (like “non-progression” and “none”) reflects how music mirrors human experience—sometimes it follows a path, sometimes it doesn't.
//
// </Details>
// ```

// %% [markdown]
// ```{margin}
//
// <Details>
//    <Summary></Summary>
//
// Of the three—**Bach, Mozart, and Beethoven**—**Beethoven** is firmly in the **V7 zone**. The **V7 chord** represents **tension**, instability, and the anticipation of resolution, and Beethoven's music is often characterized by intense emotional struggle and dramatic conflict, both musically and personally. He embodies that **climactic moment** before release, where the listener is suspended in uncertainty and tension.
//
// Beethoven’s work, especially in his later years, is full of **discord and resolution**, pushing musical boundaries and emotional depth to their limits. His symphonies and sonatas have moments of profound **tension**, where the music seems to be straining toward something greater, before ultimately resolving in ways that are often unexpected but deeply satisfying. He thrives in that **struggle**, the pushing and pulling of tension—it's the very heart of his music. His compositions build up that anticipation, just like the **V7 chord**, making his eventual resolution all the more powerful.
//
// **Bach**, on the other hand, is more in the **ii7♭5 zone**—his music is **structured** and **stable**, often defined by its complexity and sense of **inevitable resolution**. He creates tension, but it’s always with the knowledge that the resolution is coming, and the listener feels secure within his contrapuntal mastery.
//
// **Mozart** sits closer to the **I zone**—his music is marked by **clarity, elegance**, and **balance**. While he certainly explores tension, it’s often fleeting, giving way to a beautiful, harmonious resolution. Mozart dances through **tension and release** with such grace that the listener rarely feels caught in the conflict the way one might with Beethoven.
//
// So, while all three composers employ tension and resolution, **Beethoven lives in that tension**, in the dramatic **V7 zone**, where the stakes are highest, and the anticipation of what comes next is palpable.
//
// </Details>
//
// ```

// %% [markdown]
// ```{margin}
//
// <Details>
//    <Summary></Summary>
//
// I’m up for the challenge! Based on the themes that have occupied you, including philosophy, art, music, morality, and your fascination with tensions and resolutions, here’s an attempt to extend the table with 20 more rows, aligning with the pattern of abstraction, narrative, and thematic progression.
//
// Let’s break it down and try to create deeper connections across various domains:
//
// I'll expand the table with themes like existentialism, technological progress, storytelling, literary criticism, moral dilemmas, and the like. Here’s how I envision the structure for the next 20 rows:
//
//
// | Chord Progression          | `ii7♭5`            | `V7`             | `i`                 |
// |---------------------------|---------------------|------------------|--------------------|
// | History                    | Reverence           | Inference        | Deliverance        |
// | Narrative Arc              | Depart              | Struggle         | Return             |
// | Levels of Abstraction      | Art                 | Science          | Morality           |
// | Uses & Abuses of History   | Worship             | Interpret        | Reinterpret        |
// | Nomenclature               | Antiquary           | Monumental       | Critical           |
// | Existentialism             | Anxiety             | Nihilism         | Redemption         |
// | Technological Progress     | Innovation          | Disruption       | Integration        |
// | Storytelling               | Setup               | Conflict         | Resolution         |
// | Moral Dilemmas             | Guilt               | Choice           | Forgiveness        |
// | Literary Criticism         | Symbolism           | Interpretation   | Catharsis          |
// | Art Movements              | Classical           | Modern           | `Postmodern`         |
// | Political Ideologies       | Conservatism        | Liberalism       | Progressivism      |
// | Economic Systems           | Feudalism           | Capitalism       | Socialism          |
// | Social Constructs          | Tradition           | Reform           | Revolution         |
// | Music                      | Tension             | Climax           | Resolution         |
// | The Hero’s Journey         | Call to Adventure   | Trials           | Transformation     |
// | Philosophical Inquiry      | Doubt               | Question         | Insight            |
// | Power Dynamics             | Control             | Rebellion        | Liberation         |
// | Time                       | Past                | Present          | Future             |
// | Human Condition            | Suffering           | Perseverance     | Enlightenment      |
// | Identity                   | Self-Discovery      | Crisis           | Acceptance         |
//
// ---
//
// This structure is built to reflect the major thematic arcs that connect your ongoing interests—whether they be philosophical, artistic, or narrative. Each new row follows the familiar **ii7♭5-V7-i** progression, mapping tensions and resolutions across different conceptual realms. This classical emotional arc is evident in both Dostoevsky & Marx, but outrightly rejected by Nietzsche who is all for the `eternal recurrence of the same` `V7` with all iterations of tensions, extensions & alterations
//
// Let me know if this sparks something for you or if you'd like further tweaks!
// Let’s score Dostoevsky, Nietzsche, and Marx on the extended themes, focusing on how much each thinker dealt with them, and using their vocabulary or worldview to map out their engagement.
//
// ---
//
// | Themes                     | Dostoevsky's Score | `Nietzsche's` Score | Marx's Score  |
// |----------------------------|--------------------|-------------------|---------------|
// | **Chord Progression**       | Conflict-Resolution | Dionysian<strike>Apollonian</strike> | Antithesis-Synthesis |
// | **History**                 | Religious History | `Eternal Recurrence` | Class Struggle |
// | **Narrative Arc**           | Redemption Arc     | Will to Power     | Revolution    |
// | **Levels of Abstraction**   | Faith vs Reason    | `Beyond` Good & Evil | Materialism   |
// | **Uses & Abuses of History**| Personal Salvation | Genealogy of Morals| Historical Materialism |
// | **Nomenclature**            | Sin, Guilt, Redemption | `Übermensch`        | Proletariat, Bourgeoisie |
// | **Existentialism**          | Deeply Central     | Strongly Central  | Peripheral    |
// | **Technological Progress**  | Moral Turmoil      | Concerned with `Modernity` | Industrialization |
// | **Storytelling**            | Rich in Symbolism  | Aphoristic        | Economic Narratives |
// | **Moral Dilemmas**          | Crucial            | Rejection of Morality | Class-based Ethics |
// | **Literary Criticism**      | Religious Allegory | Archetypes, Myth  | Economic Base & Superstructure |
// | **Art Movements**           | Deeply Introspective | Dionysian Art     | Focus on Propaganda |
// | **Political Ideologies**    | Rejection of Modernity | Anti-State       | Communist Ideals |
// | **Economic Systems**        | Spiritual Conflict | Critic of Capitalism | Critique of Capitalism |
// | **Social Constructs**       | Alienation         | Rejection of Herd Morality | Class Division |
// | **Music**                   | Tension and Resolution | Life-Affirming Struggle | March of Progress |
// | **The Hero’s Journey**      | Redemption Story   | Tragic Hero       | Collective Uprising |
// | **Philosophical Inquiry**   | Introspection, God | Rebellion against Morality | Economic Determinism |
// | **Power Dynamics**          | Sin and Redemption | Power as Struggle | Class Warfare |
// | **Time**                    | Theological Time   | Eternal Recurrence| Historical Materialism |
// | **Human Condition**         | Suffering & Grace  | Suffering & Overcoming | Collective Struggle |
// | **Identity**                | Crisis of Faith    | Self-Creation     | Class Identity |
//
// ---
//
// <h3> Explanation:</h3>
//
// - **Dostoevsky**: His focus was often on **conflict**, **moral dilemmas**, and the **human condition**. He frequently explored themes like **suffering, faith, and redemption**, and his narratives often revolved around deeply introspective **spiritual conflicts**. He wasn’t as focused on political or economic systems as Marx but was highly attuned to existential and theological themes.
//
// - **Nietzsche**: His ideas centered on **individual power**, **self-creation**, and **struggle**. He rejected traditional moral systems, focusing instead on ideas like the **will to power** and the **Übermensch**. For him, art, philosophy, and **eternal recurrence** were essential to human existence, and he was concerned with the **uses and abuses of history** in shaping human thought.
//
// - **Marx**: He viewed the world through a **materialist** lens, focusing on **class struggle** and the dynamics of **capitalism** and **revolution**. His concern with economic systems, political ideologies, and social constructs dominated his work. His narrative arcs are those of **collective struggle** rather than individual redemption or power dynamics.
//
// This table could provide a way to quickly assess how these thinkers intersect with the themes that engage you. Let me know if you’d like further modifications!
//
// </Details>
//
// ```

// %% [markdown]
//                     1. Input
//                             \
//            2. Processing -> 4. Art -> 5. Science -> 6. Morality
//                             /
//                             3. Output -> Feedback
//
//
//
//  <iframe
//     src="https://www.youtube.com/embed/TrPlaCG2btk"
//     title="YouTube video player"
//     style="width: 100%; height: 500px"
//     frameborder="0"
//     allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
//     allowfullscreen>
// </iframe>
//
// ```{figure} ../figures/blanche.*
// ---
// width: 1
// height: 1
// ---
// _Life & cybernetics_. The "Arts" encode aesthetics, religion, theology, and spirituality of mankind throughout history & have the distinguishing feature of `reverence`. It is the irreverent sciences that make `inferences` strictly by testing the present against historical data. Morality seeks `deliverance` from the evil deeds of history, present, and future. It borrows from science by interpreting then critizing history & from the arts by reinterpreting everything afresh "as if experienced first hand.But its a third layer of abstraction, whereas art is the first level of abstraction that `reharms` life as experienced
// ```

// %%
qui {
clear 
rm code.png   
global repo "https://raw.githubusercontent.com/abikesa/philosophy/main/kitabo/ensi/data/" 
if 0 {
    See 'pdfs/Work Note.png' for App
//1. data-analysis: cox-regression (rdc restricted-access)
stcox var1-58, basesurv(s0_nondonor)
matrix b=e(b)
mkmat beta1-58, matrix(b_nondonor)
keep _t s0_nondonor
export delimited s0_nondonor.csv, replace 
}
//2. processing: beta-coefficients (zero disclosure-risk)
import delimited "${repo}b_nondonor.csv", clear 
local i = 1
foreach var of varlist * {   // this loops over all variables in the dataset
    rename `var' var`i'
    local i = `i' + 1
}
mkmat var1-var58, matrix(beta)
//3. flexing: scenario-vector (demonstration-only; app for eui)
import delimited "${repo}SV_nondonor.csv", clear 
local i = 1
foreach var of varlist * {   // this loops over all variables in the dataset
    rename `var' var`i'
    local i = `i' + 1
}
mkmat var1-var58, matrix(SV)
//4. art: base-case (embodies, realizes, transcends usual stuff)
import delimited "${repo}s0_nondonor.csv", clear 
l in 1/10
g f0 = (1 - s0_nondonor)*100
//5. science: logHR-se.logHR (decodes everything, communicates to fellows)
matrix logHR=beta*SV'
matrix list logHR
//6. morality: threshold, draw-the-line (all 'bout dre for the eui)
g f1 = f0*exp(logHR[1,1])
line f0 f1 _t, ///
   sort connect(step step) ylab(0(20)100) ///
   legend(lab(1 "Base-Case") lab(2 "Scenario"))  
graph export ../figures/code.png, replace  
}
// Out:
// file /Users/apollo/.stata_kernel_cache/graph1.svg saved as SVG format
// file /Users/apollo/.stata_kernel_cache/graph1.pdf saved as PDF format

// %% [markdown]
// ![](../figures/code.png)

// %%
import delimited "${repo}beta_coefficients_58.csv", clear 
list variable
// Out:
// (encoding automatically selected: ISO-8859-1)
// (2 vars, 58 obs)
//
//
//      +-----------------------------+
//      |                    variable |
//      |-----------------------------|
//   1. |                 diabetes_No |
//   2. |                diabetes_Yes |
//   3. |                  insulin_No |
//   4. |                 insulin_Yes |
//   5. |                 dia_pill_No |
//      |-----------------------------|
//   6. |                dia_pill_Yes |
//   7. |             hypertension_No |
//   8. |            hypertension_Yes |
//   9. |     hypertension_Don't_Know |
//  10. |                 hbp_pill_No |
//      |-----------------------------|
//  11. |                hbp_pill_Yes |
//  12. |                    smoke_No |
//  13. |                   smoke_Yes |
//  14. |       income_adjusted_<5000 |
//  15. |   income_adjusted_5000-9999 |
//      |-----------------------------|
//  16. | income_adjusted_10000-14999 |
//  17. | income_adjusted_15000-19999 |
// ...

// %% [markdown]
// <Details>
//    <Summary></Summary>
//
//    <iframe src="https://www.youtube.com/embed/GzogU1RncbU" width="100%" height="300px" style="border:none" allow="autoplay; encrypted-media" allowfullscreen></iframe>
//
// > *Clandace Oven: Black & Jewish Reaction to her*
//
// This seems to present an argument about the complexities of historical interpretation, critique, and the abstractions we use to frame the past, particularly in how people engage with figures like Winston Churchill or regimes like Nazi Germany and Israel. It appears to delve into the nuances of reverence for history, the balance between recognizing the monumental achievements of figures and criticizing their morally reprehensible actions, and how science can help interpret but not fully judge historical events.
//
// Candace Owens and the reactions to her statements, as well as the broader tension between Jewish and Black communities on sensitive historical subjects, illustrate this well. The mention of Piers Morgan and Churchill points to how critiques of revered figures are often one-dimensional, focusing on moral condemnation without acknowledging the monumental aspects of their legacies.
//
// It seems that you're advocating for a model of critique that recognizes the antiquarian (preserving historical facts), monumental (celebrating great achievements), and critical (analyzing the flaws), suggesting that dismissing an entire legacy because of its darker sides can be intellectually lazy. This framework, if applied thoughtfully, would allow for more nuanced discussions of complex historical figures without devolving into simplistic moral judgments.
//
// There's also a point here about the danger of criticism becoming irrelevant if it lacks historical grounding or recognition of broader context. Critiques of Israel by antisemitic figures or dismissing Churchill for his imperialism without understanding the full scope of his impact are cases in point.
//
// Where do you think this approach could lead us in contemporary discussions on historical figures or events? Would it foster deeper, more productive conversations, or does it risk excusing too much?
//
// <a href="https://www.haaretz.com/opinion/2024-09-08/ty-article/.premium/israeli-society-has-truly-fallen-to-cruelty-violence-and-apathy-just-look-at-us/00000191-cd88-df60-a79b-cdfd0a370000">Notes</a>:
//
// - You accept that Hitler, `nationalist`, did this?
// - And you accept that Josef Mengele, physician, `scientist`, did that?
// - Gobbles, another Joseph, Philologist, film critique, `artist` was an evil man?
//
// Abstractions:
// - Art
// - Science
// - Morality
//
// History:
// - Reverence
// - Inference
// - Deliverance
//
// Models:
// - Antiquarian
// - Monumental
// - Critical
//
// Exchange:
// - Learn from science how to interpret history
// - Then irrelevantly criticize the evil in it
// - You don’t have to throw everything out
//
//
// 1. Piers Morgan can’t criticize Winston Churchill
// 2. Antisemitic police can’t criticize Israel
// 3. Critics are asked to state antiquarian & monumental aspects of what they attack
//
// </Details>

// %% [markdown]
// <Details>
//    <Summary></Summary>
//
//    <iframe src="https://www.youtube.com/embed/180_xij5Kgg" width="100%" height="300px" style="border:none" allow="autoplay; encrypted-media" allowfullscreen></iframe>
//
// Talking of `reverence`: Shrimp Tower!
//
// </Details>
